# %% [markdown]
# # Cara install

# %%
# jangan install tensorflow, installnya tensorflow-gpu
# pakai python 3.6.8
# %pip install tensorflow-gpu==1.5 numpy pandas scikit-learn keras matplotlib
# Out:
# Requirement already satisfied: tensorflow-directml in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (1.15.8)
# Requirement already satisfied: numpy in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (1.21.6)
# Requirement already satisfied: pandas in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (1.1.5)
# Requirement already satisfied: scikit-learn in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (1.0.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (2.1.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (0.2.2)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (1.1.2)
# Collecting numpy
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (3.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (1.17.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.6.1 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (3.19.6)
# Collecting tensorboard<1.16.0,>=1.15.0 (from tensorflow-directml)
#   Using cached tensorboard-1.15.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator==1.15.1 (from tensorflow-directml)
#   Using cached tensorflow_estimator-1.15.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (1.16.0)
# Requirement already satisfied: h5py<=2.10.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (2.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (1.62.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-directml) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anfiniti\appdata\roaming\python\python37\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (3.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (68.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (2.2.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (6.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from werkzeug>=0.11.15->tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\anfiniti\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-directml) (4.7.1)
# Using cached tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
# Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# Using cached tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
# Installing collected packages: tensorflow-estimator, numpy, tensorboard
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
# Successfully installed numpy-1.18.5 tensorboard-1.15.0 tensorflow-estimator-1.15.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\anfiniti\AppData\Local\Programs\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\anfiniti\AppData\Local\Programs\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.11.0 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorflow-estimator<2.12,>=2.11.0, but you have tensorflow-estimator 1.15.1 which is incompatible.

# %% [markdown]
# # Cek GPU

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())
# Out:
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:496: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:497: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:502: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /device:GPU:0

# %%
import tensorflow as tf

with tf.device("/device:GPU:0"):
    a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
    b = tf.constant([[1.0, 1.0], [0.0, 1.0]])
    c = tf.matmul(a, b)
    print(c)
# Out:
# Tensor("MatMul_2:0", shape=(2, 2), dtype=float32, device=/device:GPU:0)

# %%
import tensorflow as tf

print(tf.test.is_gpu_available())
# Out:
# True

# %%
import tensorflow as tf

# Cek apakah TensorFlow benar-benar menggunakan GPU
with tf.device("/device:GPU:0"):
    a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
    b = tf.constant([[5.0, 6.0], [7.0, 8.0]])
    c = tf.matmul(a, b)  # Operasi matrix multiplication

    with tf.Session() as sess:
        result = sess.run(c)
        print("Hasil operasi di GPU:", result)
# Out:
# Hasil operasi di GPU: [[19. 22.]
#  [43. 50.]]

# %%
import tensorflow as tf

# Cek daftar perangkat yang tersedia
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# Pastikan TensorFlow pakai GPU
if tf.test.is_gpu_available():
    print("✅ TensorFlow sudah menggunakan GPU")
else:
    print("❌ TensorFlow masih pakai CPU")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16731184107446750778
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 213850523
# locality {
#   bus_id: 1
# }
# incarnation: 801780188165050746
# physical_device_desc: "device: 0, name: GeForce GT 730M, pci bus id: 0000:03:00.0, compute capability: 3.5"
# ]
# ✅ TensorFlow sudah menggunakan GPU

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.test.is_gpu_available())
print("Devices available:", tf.Session().list_devices())
# Out:
# TensorFlow version: 1.5.0
# GPU Available: True
# Devices available: [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456), _DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 155130267)]

# %%
import tensorflow as tf

# Cek apakah GPU tersedia
print("Apakah GPU tersedia?", tf.test.is_gpu_available())

# Menampilkan daftar perangkat yang tersedia
from tensorflow.python.client import device_lib
print("Daftar perangkat yang terdeteksi:")
print(device_lib.list_local_devices())
# Out:
# Apakah GPU tersedia? True
# Daftar perangkat yang terdeteksi:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10857379069640336798
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 155130267
# locality {
#   bus_id: 1
# }
# incarnation: 7172878288344392020
# physical_device_desc: "device: 0, name: GeForce GT 730M, pci bus id: 0000:03:00.0, compute capability: 3.5"
# ]

# %%
import tensorflow as tf

# Dapatkan konfigurasi perangkat dari TensorFlow
devices = tf.Session().list_devices()
cpu_info = [device for device in devices if 'CPU' in device.name]
gpu_info = [device for device in devices if 'GPU' in device.name]

print("Informasi CPU:")
print(cpu_info)

print("Informasi GPU:")
print(gpu_info)

# Informasi jumlah core CPU
print(f"Jumlah core CPU: {cpu_cores}")
print(f"Jumlah GPU: {len(gpu_info)}")
print(f"CUDA GPU: {tf.test.is_built_with_cuda()}")
print(f"Jumlah CUDA GPU: {len(gpu_info)}")
# Out:
# Informasi CPU:
# [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456)]
# Informasi GPU:
# [_DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 155130267)]
# Jumlah core CPU: 4
# Jumlah GPU: 1
# CUDA GPU: True
# Jumlah CUDA GPU: 1

# %% [markdown]
# # Klasifikasi AND dengan GPU

# %%
import numpy as np

x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [1]])

# %%
import tensorflow as tf
import time

# Cek apakah GPU tersedia
print("GPU Available:", tf.test.is_gpu_available())

# Pastikan TensorFlow menggunakan GPU
with tf.device('/GPU:0'):
    a = tf.constant([[2.0, 3.0], [4.0, 5.0]])
    b = tf.constant([[1.0, 2.0], [3.0, 4.0]])

    start = time.time()
    result = tf.matmul(a, b)  # Operasi perkalian matriks
    end = time.time()

    print("Hasil Perhitungan:", result)
    print(f"Waktu Eksekusi: {end - start:.6f} detik")
# Out:
# GPU Available: True
# Hasil Perhitungan: Tensor("MatMul_1:0", shape=(2, 2), dtype=float32, device=/device:GPU:0)
# Waktu Eksekusi: 0.002998 detik

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.callbacks import ModelCheckpoint

# Cek versi TensorFlow
print("TensorFlow version:", tf.__version__)

# Definisi model
model = Sequential(
    [
        Dense(4, input_dim=2, activation="relu"),
        Dense(16, activation="relu"),
        Dense(1, activation="sigmoid"),
    ]
)

# Kompilasi model
model.compile(optimizer="SGD", loss="binary_crossentropy", metrics=["accuracy"])

# Callback untuk menyimpan model terbaik
checkpoint = ModelCheckpoint(
    "best_model.h5", monitor="accuracy", save_best_only=True, mode="max"
)

# Konfigurasi sesi TensorFlow untuk menggunakan GPU jika tersedia
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # Memungkinkan penggunaan GPU secara dinamis
session = tf.Session(config=config)

# Cek apakah GPU tersedia
device_name = "/device:GPU:0"

try:
    with tf.device(device_name):
        print("Training menggunakan GPU")
        with session.as_default():
            model.fit(x, y, epochs=100, verbose=1, callbacks=[checkpoint])
except RuntimeError as e:
    print("Gagal menggunakan GPU, menggunakan CPU sebagai fallback.")
    print("Error:", e)
    with session.as_default():
        model.fit(x, y, epochs=100, verbose=1, callbacks=[checkpoint])
# Out:
# TensorFlow version: 1.5.0
# WARNING:tensorflow:From c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py:1557: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Training menggunakan GPU
# Epoch 1/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 1s 206ms/step - loss: 0.6931 - acc: 0.7500
#
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6925 - acc: 0.7500
#
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.6919 - acc: 0.7500
#
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6913 - acc: 0.7500
#
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6907 - acc: 0.7500
#
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6901 - acc: 0.7500
#
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6894 - acc: 0.7500
#
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6888 - acc: 0.7500
#
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6882 - acc: 0.7500
#
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6876 - acc: 0.7500
#
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6870 - acc: 0.7500
#
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6864 - acc: 0.7500
#
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6859 - acc: 0.7500
#
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.6853 - acc: 0.7500
#
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6847 - acc: 0.7500
#
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6841 - acc: 0.7500
#
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6835 - acc: 0.7500
#
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6829 - acc: 0.7500
#
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6824 - acc: 0.7500
#
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6818 - acc: 0.7500
#
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6812 - acc: 0.7500
#
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.6807 - acc: 0.7500
#
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6801 - acc: 0.7500
#
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6796 - acc: 0.7500
#
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6790 - acc: 0.7500
#
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6784 - acc: 0.7500
#
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6779 - acc: 0.7500
#
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6773 - acc: 0.7500
#
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6768 - acc: 0.7500
#
# Epoch 30/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6763 - acc: 0.7500
#
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6757 - acc: 0.7500
#
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6752 - acc: 0.7500
#
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6746 - acc: 0.7500
#
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6741 - acc: 0.7500
#
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6736 - acc: 0.7500
#
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6731 - acc: 0.7500
#
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6725 - acc: 0.7500
#
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6720 - acc: 0.7500
#
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6715 - acc: 0.7500
#
# Epoch 40/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6710 - acc: 0.7500
#
# Epoch 41/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6705 - acc: 0.7500
#
# Epoch 42/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6700 - acc: 0.7500
#
# Epoch 43/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6694 - acc: 0.7500
#
# Epoch 44/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6689 - acc: 0.7500
#
# Epoch 45/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6684 - acc: 0.7500
#
# Epoch 46/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6679 - acc: 0.7500
#
# Epoch 47/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6674 - acc: 0.7500
#
# Epoch 48/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6669 - acc: 0.7500
#
# Epoch 49/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6664 - acc: 0.7500
#
# Epoch 50/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6660 - acc: 0.7500
#
# Epoch 51/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6655 - acc: 0.7500
#
# Epoch 52/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6650 - acc: 0.7500
#
# Epoch 53/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.6645 - acc: 0.7500
#
# Epoch 54/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6640 - acc: 0.7500
#
# Epoch 55/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6635 - acc: 0.7500
#
# Epoch 56/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6631 - acc: 0.7500
#
# Epoch 57/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6626 - acc: 0.7500
#
# Epoch 58/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6621 - acc: 0.7500
#
# Epoch 59/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6616 - acc: 0.7500
#
# Epoch 60/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6612 - acc: 0.7500
#
# Epoch 61/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6607 - acc: 0.7500
#
# Epoch 62/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6602 - acc: 0.7500
#
# Epoch 63/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6598 - acc: 0.7500
#
# Epoch 64/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 650us/step - loss: 0.6593 - acc: 0.7500
#
# Epoch 65/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6589 - acc: 0.7500
#
# Epoch 66/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6584 - acc: 0.7500
#
# Epoch 67/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 23ms/step - loss: 0.6580 - acc: 0.7500
#
# Epoch 68/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6575 - acc: 0.7500
#
# Epoch 69/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 16ms/step - loss: 0.6571 - acc: 0.7500
#
# Epoch 70/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.6566 - acc: 0.7500
#
# Epoch 71/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6562 - acc: 0.7500
#
# Epoch 72/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6557 - acc: 0.7500
#
# Epoch 73/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6553 - acc: 0.7500
#
# Epoch 74/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6549 - acc: 0.7500
#
# Epoch 75/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.6544 - acc: 0.7500
#
# Epoch 76/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6540 - acc: 0.7500
#
# Epoch 77/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6536 - acc: 0.7500
#
# Epoch 78/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6532 - acc: 0.7500
#
# Epoch 79/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6527 - acc: 0.7500
#
# Epoch 80/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6523 - acc: 0.7500
#
# Epoch 81/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6519 - acc: 0.7500
#
# Epoch 82/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6515 - acc: 0.7500
#
# Epoch 83/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6510 - acc: 0.7500
#
# Epoch 84/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6506 - acc: 0.7500
#
# Epoch 85/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6502 - acc: 0.7500
#
# Epoch 86/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6498 - acc: 0.7500
#
# Epoch 87/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6494 - acc: 0.7500
#
# Epoch 88/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6490 - acc: 0.7500
#
# Epoch 89/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6486 - acc: 0.7500
#
# Epoch 90/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6482 - acc: 0.7500
#
# Epoch 91/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6478 - acc: 0.7500
#
# Epoch 92/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6474 - acc: 0.7500
#
# Epoch 93/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6470 - acc: 0.7500
#
# Epoch 94/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6466 - acc: 0.7500
#
# Epoch 95/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6462 - acc: 0.7500
#
# Epoch 96/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6458 - acc: 0.7500
#
# Epoch 97/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6454 - acc: 0.7500
#
# Epoch 98/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6450 - acc: 0.7500
#
# Epoch 99/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6447 - acc: 0.7500
#
# Epoch 100/100
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6443 - acc: 0.7500

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.callbacks import ModelCheckpoint

# Define the model
model = Sequential(
    [
        Dense(4, input_dim=2, activation="relu"),
        Dense(16, activation="relu"),
        Dense(1, activation="sigmoid"),
    ]
)

# Compile the model
model.compile(optimizer="SGD", loss="binary_crossentropy", metrics=["accuracy"])

# Define model checkpoint callback
checkpoint = ModelCheckpoint(
    "best_model.h5", monitor="accuracy", save_best_only=True, mode="max"
)

# Fit the model using CPU
with tf.device("/cpu:0"):
    model.fit(x, y, epochs=1000, verbose=1, callbacks=[checkpoint])
# Out:
# Epoch 1/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 88ms/step - loss: 0.6948 - acc: 0.7500
#
# Epoch 2/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6942 - acc: 0.7500
#
# Epoch 3/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 17ms/step - loss: 0.6933 - acc: 0.7500
#
# Epoch 4/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6924 - acc: 0.7500
#
# Epoch 5/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6915 - acc: 0.7500
#
# Epoch 6/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6907 - acc: 0.7500
#
# Epoch 7/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6898 - acc: 0.7500
#
# Epoch 8/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6890 - acc: 0.7500
#
# Epoch 9/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6881 - acc: 0.7500
#
# Epoch 10/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6873 - acc: 0.7500
#
# Epoch 11/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6864 - acc: 0.7500
#
# Epoch 12/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6856 - acc: 0.7500
#
# Epoch 13/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6848 - acc: 0.7500
#
# Epoch 14/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6840 - acc: 0.7500
#
# Epoch 15/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6831 - acc: 0.7500
#
# Epoch 16/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6823 - acc: 0.7500
#
# Epoch 17/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6815 - acc: 0.5000
#
# Epoch 18/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6807 - acc: 0.5000
#
# Epoch 19/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6799 - acc: 0.5000
#
# Epoch 20/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6791 - acc: 0.7500
#
# Epoch 21/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6784 - acc: 0.7500
#
# Epoch 22/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 17ms/step - loss: 0.6776 - acc: 0.7500
#
# Epoch 23/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6768 - acc: 0.7500
#
# Epoch 24/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6760 - acc: 0.7500
#
# Epoch 25/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6753 - acc: 0.7500
#
# Epoch 26/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6745 - acc: 0.7500
#
# Epoch 27/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6738 - acc: 0.7500
#
# Epoch 28/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6730 - acc: 0.7500
#
# Epoch 29/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6723 - acc: 0.7500
#
# Epoch 30/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6715 - acc: 0.7500
#
# Epoch 31/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.6708 - acc: 0.7500
#
# Epoch 32/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6700 - acc: 0.7500
#
# Epoch 33/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6693 - acc: 0.7500
#
# Epoch 34/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6686 - acc: 0.7500
#
# Epoch 35/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6679 - acc: 0.7500
#
# Epoch 36/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6672 - acc: 0.7500
#
# Epoch 37/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6665 - acc: 0.7500
#
# Epoch 38/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6658 - acc: 0.7500
#
# Epoch 39/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6651 - acc: 0.7500
#
# Epoch 40/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6644 - acc: 0.7500
#
# Epoch 41/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6637 - acc: 0.7500
#
# Epoch 42/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6630 - acc: 0.7500
#
# Epoch 43/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6623 - acc: 0.7500
#
# Epoch 44/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6616 - acc: 0.7500
#
# Epoch 45/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6610 - acc: 0.7500
#
# Epoch 46/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6603 - acc: 0.7500
#
# Epoch 47/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6596 - acc: 0.7500
#
# Epoch 48/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6590 - acc: 0.7500
#
# Epoch 49/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6583 - acc: 0.7500
#
# Epoch 50/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6576 - acc: 0.7500
#
# Epoch 51/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.6570 - acc: 0.7500
#
# Epoch 52/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6563 - acc: 0.7500
#
# Epoch 53/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6557 - acc: 0.7500
#
# Epoch 54/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6551 - acc: 0.7500
#
# Epoch 55/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6544 - acc: 0.7500
#
# Epoch 56/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6538 - acc: 0.7500
#
# Epoch 57/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6532 - acc: 0.7500
#
# Epoch 58/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6525 - acc: 0.7500
#
# Epoch 59/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6519 - acc: 0.7500
#
# Epoch 60/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6513 - acc: 0.7500
#
# Epoch 61/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6507 - acc: 0.7500
#
# Epoch 62/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.6501 - acc: 0.7500
#
# Epoch 63/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6495 - acc: 0.7500
#
# Epoch 64/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6489 - acc: 0.7500
#
# Epoch 65/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 18ms/step - loss: 0.6483 - acc: 0.7500
#
# Epoch 66/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6477 - acc: 0.7500
#
# Epoch 67/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6471 - acc: 0.7500
#
# Epoch 68/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6465 - acc: 0.7500
#
# Epoch 69/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6460 - acc: 0.7500
#
# Epoch 70/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6454 - acc: 0.7500
#
# Epoch 71/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6448 - acc: 0.7500
#
# Epoch 72/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6442 - acc: 0.7500
#
# Epoch 73/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6437 - acc: 0.7500
#
# Epoch 74/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6431 - acc: 0.7500
#
# Epoch 75/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6425 - acc: 0.7500
#
# Epoch 76/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6420 - acc: 0.7500
#
# Epoch 77/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6414 - acc: 0.7500
#
# Epoch 78/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 21ms/step - loss: 0.6409 - acc: 0.7500
#
# Epoch 79/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 28ms/step - loss: 0.6403 - acc: 0.7500
#
# Epoch 80/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6398 - acc: 0.7500
#
# Epoch 81/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 20ms/step - loss: 0.6393 - acc: 0.7500
#
# Epoch 82/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6387 - acc: 0.7500
#
# Epoch 83/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 20ms/step - loss: 0.6382 - acc: 0.7500
#
# Epoch 84/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6376 - acc: 0.7500
#
# Epoch 85/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6371 - acc: 0.7500
#
# Epoch 86/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6366 - acc: 0.7500
#
# Epoch 87/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6361 - acc: 0.7500
#
# Epoch 88/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6356 - acc: 0.7500
#
# Epoch 89/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6350 - acc: 0.7500
#
# Epoch 90/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6345 - acc: 0.7500
#
# Epoch 91/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6340 - acc: 0.7500
#
# Epoch 92/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6335 - acc: 0.7500
#
# Epoch 93/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6330 - acc: 0.7500
#
# Epoch 94/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6325 - acc: 0.7500
#
# Epoch 95/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6320 - acc: 0.7500
#
# Epoch 96/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6315 - acc: 0.7500
#
# Epoch 97/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6310 - acc: 0.7500
#
# Epoch 98/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6306 - acc: 0.7500
#
# Epoch 99/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6301 - acc: 0.7500
#
# Epoch 100/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6296 - acc: 0.7500
#
# Epoch 101/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6291 - acc: 0.7500
#
# Epoch 102/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6286 - acc: 0.7500
#
# Epoch 103/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6282 - acc: 0.7500
#
# Epoch 104/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6277 - acc: 0.7500
#
# Epoch 105/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6272 - acc: 0.7500
#
# Epoch 106/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6268 - acc: 0.7500
#
# Epoch 107/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6263 - acc: 0.7500
#
# Epoch 108/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.6259 - acc: 0.7500
#
# Epoch 109/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6254 - acc: 0.7500
#
# Epoch 110/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6250 - acc: 0.7500
#
# Epoch 111/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6245 - acc: 0.7500
#
# Epoch 112/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6240 - acc: 0.7500
#
# Epoch 113/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6236 - acc: 0.7500
#
# Epoch 114/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6232 - acc: 0.7500
#
# Epoch 115/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6227 - acc: 0.7500
#
# Epoch 116/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.6223 - acc: 0.7500
#
# Epoch 117/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6219 - acc: 0.7500
#
# Epoch 118/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6214 - acc: 0.7500
#
# Epoch 119/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6210 - acc: 0.7500
#
# Epoch 120/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6206 - acc: 0.7500
#
# Epoch 121/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6201 - acc: 0.7500
#
# Epoch 122/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6197 - acc: 0.7500
#
# Epoch 123/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6193 - acc: 0.7500
#
# Epoch 124/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6189 - acc: 0.7500
#
# Epoch 125/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6185 - acc: 0.7500
#
# Epoch 126/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6181 - acc: 0.7500
#
# Epoch 127/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6176 - acc: 0.7500
#
# Epoch 128/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.6172 - acc: 0.7500
#
# Epoch 129/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6168 - acc: 0.7500
#
# Epoch 130/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6164 - acc: 0.7500
#
# Epoch 131/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6159 - acc: 0.7500
#
# Epoch 132/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6155 - acc: 0.7500
#
# Epoch 133/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6151 - acc: 0.7500
#
# Epoch 134/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6147 - acc: 0.7500
#
# Epoch 135/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6143 - acc: 0.7500
#
# Epoch 136/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6139 - acc: 0.7500
#
# Epoch 137/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6135 - acc: 0.7500
#
# Epoch 138/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6131 - acc: 0.7500
#
# Epoch 139/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6127 - acc: 0.7500
#
# Epoch 140/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6123 - acc: 0.7500
#
# Epoch 141/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6119 - acc: 0.7500
#
# Epoch 142/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.6115 - acc: 0.7500
#
# Epoch 143/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6111 - acc: 0.7500
#
# Epoch 144/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6108 - acc: 0.7500
#
# Epoch 145/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6104 - acc: 0.7500
#
# Epoch 146/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 17ms/step - loss: 0.6100 - acc: 0.7500
#
# Epoch 147/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6096 - acc: 0.7500
#
# Epoch 148/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.6093 - acc: 0.7500
#
# Epoch 149/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6089 - acc: 0.7500
#
# Epoch 150/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 16ms/step - loss: 0.6086 - acc: 0.7500
#
# Epoch 151/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 19ms/step - loss: 0.6082 - acc: 0.7500
#
# Epoch 152/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6079 - acc: 0.7500
#
# Epoch 153/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6075 - acc: 0.7500
#
# Epoch 154/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.6072 - acc: 0.7500
#
# Epoch 155/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6068 - acc: 0.7500
#
# Epoch 156/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6065 - acc: 0.7500
#
# Epoch 157/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.6061 - acc: 0.7500
#
# Epoch 158/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.6058 - acc: 0.7500
#
# Epoch 159/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6055 - acc: 0.7500
#
# Epoch 160/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6051 - acc: 0.7500
#
# Epoch 161/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6048 - acc: 0.7500
#
# Epoch 162/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6045 - acc: 0.7500
#
# Epoch 163/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6042 - acc: 0.7500
#
# Epoch 164/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6038 - acc: 0.7500
#
# Epoch 165/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.6035 - acc: 0.7500
#
# Epoch 166/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.6032 - acc: 0.7500
#
# Epoch 167/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6029 - acc: 0.7500
#
# Epoch 168/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6026 - acc: 0.7500
#
# Epoch 169/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.6022 - acc: 0.7500
#
# Epoch 170/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.6019 - acc: 0.7500
#
# Epoch 171/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6016 - acc: 0.7500
#
# Epoch 172/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6013 - acc: 0.7500
#
# Epoch 173/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 16ms/step - loss: 0.6010 - acc: 0.7500
#
# Epoch 174/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.6007 - acc: 0.7500
#
# Epoch 175/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.6004 - acc: 0.7500
#
# Epoch 176/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.6001 - acc: 0.7500
#
# Epoch 177/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.5998 - acc: 0.7500
#
# Epoch 178/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5995 - acc: 0.7500
#
# Epoch 179/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.5992 - acc: 0.7500
#
# Epoch 180/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.5989 - acc: 0.7500
#
# Epoch 181/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.5986 - acc: 0.7500
#
# Epoch 182/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5983 - acc: 0.7500
#
# Epoch 183/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5980 - acc: 0.7500
#
# Epoch 184/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5977 - acc: 0.7500
#
# Epoch 185/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5975 - acc: 0.7500
#
# Epoch 186/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 12ms/step - loss: 0.5972 - acc: 0.7500
#
# Epoch 187/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.5969 - acc: 0.7500
#
# Epoch 188/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.5966 - acc: 0.7500
#
# Epoch 189/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.5963 - acc: 0.7500
#
# Epoch 190/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.5961 - acc: 0.7500
#
# Epoch 191/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.5958 - acc: 0.7500
#
# Epoch 192/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.5955 - acc: 0.7500
#
# Epoch 193/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5952 - acc: 0.7500
#
# Epoch 194/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.5950 - acc: 0.7500
#
# Epoch 195/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5947 - acc: 0.7500
#
# Epoch 196/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.5944 - acc: 0.7500
#
# Epoch 197/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5942 - acc: 0.7500
#
# Epoch 198/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5939 - acc: 0.7500
#
# Epoch 199/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5936 - acc: 0.7500
#
# Epoch 200/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5934 - acc: 0.7500
#
# Epoch 201/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.5931 - acc: 0.7500
#
# Epoch 202/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.5929 - acc: 0.7500
#
# Epoch 203/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.5926 - acc: 0.7500
#
# Epoch 204/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.5924 - acc: 0.7500
#
# Epoch 205/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.5921 - acc: 0.7500
#
# Epoch 206/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5918 - acc: 0.7500
#
# Epoch 207/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5916 - acc: 0.7500
#
# Epoch 208/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.5914 - acc: 0.7500
#
# Epoch 209/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.5911 - acc: 0.7500
#
# Epoch 210/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 25ms/step - loss: 0.5909 - acc: 0.7500
#
# Epoch 211/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 19ms/step - loss: 0.5906 - acc: 0.7500
#
# Epoch 212/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.5904 - acc: 0.7500
#
# Epoch 213/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 17ms/step - loss: 0.5901 - acc: 0.7500
#
# Epoch 214/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.5899 - acc: 0.7500
#
# Epoch 215/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.5897 - acc: 0.7500
#
# Epoch 216/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.5894 - acc: 0.7500
#
# Epoch 217/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.5892 - acc: 0.7500
#
# Epoch 218/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.5889 - acc: 0.7500
#
# Epoch 219/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5887 - acc: 0.7500
#
# Epoch 220/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.5885 - acc: 0.7500
#
# Epoch 221/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.5883 - acc: 0.7500
#
# Epoch 222/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.5880 - acc: 0.7500
#
# Epoch 223/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.5878 - acc: 0.7500
#
# Epoch 224/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.5876 - acc: 0.7500
#
# Epoch 225/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.5874 - acc: 0.7500
#
# Epoch 226/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.5871 - acc: 0.7500
#
# Epoch 227/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.5869 - acc: 0.7500
#
# Epoch 228/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# ...
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4854 - acc: 0.7500
#
# Epoch 926/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4852 - acc: 0.7500
#
# Epoch 927/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4849 - acc: 0.7500
#
# Epoch 928/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4847 - acc: 0.7500
#
# Epoch 929/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4844 - acc: 0.7500
#
# Epoch 930/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4841 - acc: 0.7500
#
# Epoch 931/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4839 - acc: 0.7500
#
# Epoch 932/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4836 - acc: 0.7500
#
# Epoch 933/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.4834 - acc: 0.7500
#
# Epoch 934/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 16ms/step - loss: 0.4831 - acc: 0.7500
#
# Epoch 935/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4829 - acc: 0.7500
#
# Epoch 936/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.4826 - acc: 0.7500
#
# Epoch 937/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4824 - acc: 0.7500
#
# Epoch 938/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.4821 - acc: 0.7500
#
# Epoch 939/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4819 - acc: 0.7500
#
# Epoch 940/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4816 - acc: 0.7500
#
# Epoch 941/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4813 - acc: 0.7500
#
# Epoch 942/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4811 - acc: 0.7500
#
# Epoch 943/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4808 - acc: 0.7500
#
# Epoch 944/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4806 - acc: 0.7500
#
# Epoch 945/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.4803 - acc: 0.7500
#
# Epoch 946/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 22ms/step - loss: 0.4800 - acc: 0.7500
#
# Epoch 947/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4798 - acc: 0.7500
#
# Epoch 948/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 30ms/step - loss: 0.4795 - acc: 0.7500
#
# Epoch 949/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 31ms/step - loss: 0.4793 - acc: 0.7500
#
# Epoch 950/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4790 - acc: 0.7500
#
# Epoch 951/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4787 - acc: 0.7500
#
# Epoch 952/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4785 - acc: 0.7500
#
# Epoch 953/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4782 - acc: 0.7500
#
# Epoch 954/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4780 - acc: 0.7500
#
# Epoch 955/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4777 - acc: 0.7500
#
# Epoch 956/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4774 - acc: 0.7500
#
# Epoch 957/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 3ms/step - loss: 0.4772 - acc: 0.7500
#
# Epoch 958/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4769 - acc: 0.7500
#
# Epoch 959/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 2ms/step - loss: 0.4766 - acc: 0.7500
#
# Epoch 960/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 13ms/step - loss: 0.4764 - acc: 0.7500
#
# Epoch 961/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.4761 - acc: 0.7500
#
# Epoch 962/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4758 - acc: 0.7500
#
# Epoch 963/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.4756 - acc: 0.7500
#
# Epoch 964/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.4753 - acc: 0.7500
#
# Epoch 965/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 21ms/step - loss: 0.4750 - acc: 0.7500
#
# Epoch 966/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 16ms/step - loss: 0.4748 - acc: 0.7500
#
# Epoch 967/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4745 - acc: 0.7500
#
# Epoch 968/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4742 - acc: 0.7500
#
# Epoch 969/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4740 - acc: 0.7500
#
# Epoch 970/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4737 - acc: 0.7500
#
# Epoch 971/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 41ms/step - loss: 0.4734 - acc: 0.7500
#
# Epoch 972/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 19ms/step - loss: 0.4732 - acc: 0.7500
#
# Epoch 973/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.4729 - acc: 0.7500
#
# Epoch 974/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 22ms/step - loss: 0.4726 - acc: 0.7500
#
# Epoch 975/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.4723 - acc: 0.7500
#
# Epoch 976/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 29ms/step - loss: 0.4721 - acc: 0.7500
#
# Epoch 977/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.4718 - acc: 0.7500
#
# Epoch 978/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4715 - acc: 0.7500
#
# Epoch 979/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.4713 - acc: 0.7500
#
# Epoch 980/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 7ms/step - loss: 0.4710 - acc: 0.7500
#
# Epoch 981/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 14ms/step - loss: 0.4707 - acc: 0.7500
#
# Epoch 982/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 11ms/step - loss: 0.4704 - acc: 0.7500
#
# Epoch 983/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.4702 - acc: 0.7500
#
# Epoch 984/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 6ms/step - loss: 0.4699 - acc: 0.7500
#
# Epoch 985/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 21ms/step - loss: 0.4696 - acc: 0.7500
#
# Epoch 986/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 34ms/step - loss: 0.4693 - acc: 0.7500
#
# Epoch 987/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4691 - acc: 0.7500
#
# Epoch 988/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 21ms/step - loss: 0.4688 - acc: 0.7500
#
# Epoch 989/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 31ms/step - loss: 0.4685 - acc: 0.7500
#
# Epoch 990/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 15ms/step - loss: 0.4682 - acc: 0.7500
#
# Epoch 991/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 19ms/step - loss: 0.4680 - acc: 0.7500
#
# Epoch 992/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 8ms/step - loss: 0.4677 - acc: 0.7500
#
# Epoch 993/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 22ms/step - loss: 0.4674 - acc: 0.7500
#
# Epoch 994/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4671 - acc: 0.7500
#
# Epoch 995/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4668 - acc: 0.7500
#
# Epoch 996/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 10ms/step - loss: 0.4666 - acc: 0.7500
#
# Epoch 997/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 9ms/step - loss: 0.4663 - acc: 0.7500
#
# Epoch 998/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 4ms/step - loss: 0.4660 - acc: 0.7500
#
# Epoch 999/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 5ms/step - loss: 0.4657 - acc: 0.7500
#
# Epoch 1000/1000
# WARNING:tensorflow:Can save best model only with accuracy available, skipping.
# 4/4 [==============================]4/4 [==============================] - 0s 20ms/step - loss: 0.4655 - acc: 0.7500

# %%
z = np.array([[1, 0]])
predictions = model.predict(x)
print("Prediksi:")
print(predictions)
# Out:
# Prediksi:
# [[0.21665989]
#  [0.28373137]
#  [0.32893437]
#  [0.4131659 ]]

# %%
binary_predictions = (predictions > 0.5).astype(int)
print("Prediksi:")
print(binary_predictions)
# Out:
# Prediksi:
# [[0]
#  [0]
#  [0]
#  [0]]

# %% [markdown]
# # Disini mulai Klasifikasi CNN dengan GPU NVIDIA 730M

# %%
import tensorflow as tf
from tensorflow.python.keras.datasets import cifar10
from tensorflow.python.keras.utils import to_categorical
from tensorflow.python.keras.callbacks import ModelCheckpoint
import time


# # Load dataset CIFAR-10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# # Normalisasi data ke range 0-1
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# # Konversi label ke one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# # Model CNN untuk CIFAR-10
def create_model():
    model = tf.keras.models.Sequential(
        [
            tf.keras.layers.Conv2D(32, (3, 3), activation="relu", input_shape=(32, 32, 3)),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), activation="relu"),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(128, (3, 3), activation="relu"),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(128, activation="relu"),
            tf.keras.layers.Dense(256, activation="relu"),
            tf.keras.layers.Dense(10, activation="softmax"),
        ]
    )
    return model

# # Kompilasi model
model = create_model()
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# # Define model checkpoint callback
checkpoint1 = ModelCheckpoint("model_CNN_NVIDIA_GT730M_1.h5", monitor="val_acc", save_best_only=True, mode="max")
checkpoint2 = ModelCheckpoint("model_CNN_NVIDIA_GT730M_2.h5", monitor="val_acc", save_best_only=True, mode="max")

# # # Jalankan training di GPU jika tersedia
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True


with tf.device("/job:localhost/replica:0/task:0/device:GPU:0"):
    print('Training menggunakan GPU...')
    start_time = time.time()
    history = model.fit(
        x_train,
        y_train,
        epochs=1,
        batch_size=64,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint1],
        verbose=1,
    )
    end_time = time.time()
    print(f"Waktu yang dibutuhkan untuk 1 epoch: {end_time - start_time:.2f} detik")
# Out:
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:496: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:497: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\dtypes.py:502: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py:3086: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py:1557: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Training menggunakan GPU...
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/1
# 50000/50000 [==============================]50000/50000 [==============================] - 53s 1ms/step - loss: 1.5468 - acc: 0.4300 - val_loss: 1.2722 - val_acc: 0.5402
#
# Waktu yang dibutuhkan untuk 1 epoch: 53.36 detik

# %%
import os

# Matikan GPU sebelum eksekusi CPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

with tf.device("/job:localhost/replica:0/task:0/device:CPU:0"):
    print('Training menggunakan CPU...')
    start_time = time.time()
    history = model.fit(
        x_train,
        y_train,
        epochs=1,
        batch_size=64,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint2],
        verbose=1,
    )
    end_time = time.time()
    print(f"Waktu yang dibutuhkan untuk 1 epoch: {end_time - start_time:.2f} detik")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-fd84e0583d1c> in <module>
#       4 os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
#       5
# ----> 6 with tf.device("/job:localhost/replixca:0/task:0/device:CPU:0"):
#       7     print('Training menggunakan CPU...')
#       8     start_time = time.time()
#
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\ops.py in device(self, device_name_or_function)
#    4025     if (device_name_or_function is not None and
#    4026         not callable(device_name_or_function)):
# -> 4027       device_function = pydev.merge_device(device_name_or_function)
#    4028     else:
#    4029       device_function = device_name_or_function
#
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\device.py in merge_device(spec)
#     280   """
#     281   if not isinstance(spec, DeviceSpec):
# --> 282     spec = DeviceSpec.from_string(spec or "")
#     283   def _device_function(node_def):
#     284     current_device = DeviceSpec.from_string(node_def.device or "")
#
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\device.py in from_string(spec)
#     226       A DeviceSpec.
#     227     """
# --> 228     return DeviceSpec().parse_from_string(spec)
#     229
#     230
#
# c:\Users\anfiniti\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\device.py in parse_from_string(self, spec)
#     169             self.device_index = int(y[2])
#     170         elif ly and y[0] != "":  # pylint: disable=g-explicit-bool-comparison
# --> 171           raise ValueError("Unknown attribute: '%s' in '%s'" % (y[0], spec))
#     172
#     173     return self
#
# ValueError: Unknown attribute: 'replixca' in '/job:localhost/replixca:0/task:0/device:CPU:0'

# %%
# Load model from checkpoint model_CNN_NVIDIA_GT730M_1.h5 atau hasil dari GPU
model.load_weights("model_CNN_NVIDIA_GT730M_1.h5")

# Evaluasi model
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Akurasi pada dataset uji:", test_acc)
# Out:
# 10000/10000 [==============================]10000/10000 [==============================] - 4s 392us/step
#
# Akurasi pada dataset uji: 0.6163

# %%
# Mencari epoch dengan akurasi validasi terbaik
best_epoch = max(enumerate(history.history["val_acc"]), key=lambda x: x[1])

# Menampilkan epoch terbaik
print(
    f"Epoch terbaik: {best_epoch[0] + 1} dengan akurasi validasi: {best_epoch[1]:.4f}"
)
# Out:
# Epoch terbaik: 1 dengan akurasi validasi: 0.6163

# %%
import numpy as np

import matplotlib.pyplot as plt

# Select a single image from the test set
index = 9999  # Change this index to test different images
test_image = x_test[index]
test_label = y_test[index]

# Display the image
plt.imshow(test_image)
plt.title(f"True Label: {np.argmax(test_label)}")
plt.show()

# Preprocess the image
test_image = np.expand_dims(test_image, axis=0)

# Predict the label of the image
predicted_label = model.predict(test_image)
predicted_class = np.argmax(predicted_label)

print(f"Predicted Label: {predicted_class}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-7ed01689ec7c> in <module>
#       1 import numpy as np
#       2
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5 # Select a single image from the test set
#
# ModuleNotFoundError: No module named 'matplotlib'
